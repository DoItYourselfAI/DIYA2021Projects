# %% [markdown]
# # EDA
# - Pearson heatmap

# %%
import pickle
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
with open('pickles/dangjin_merged.pkl','rb') as f:
    dangjin_merged = pickle.load(f)
with open('pickles/ulsan_merged.pkl','rb') as f:
    ulsan_merged = pickle.load(f)

# %% [markdown]
# ## Describe

# %%
dangjin_merged.describe()
# Out:
#        Temperature_fcst  Humidity_fcst    Cloud_fcst   Wind_X_fcst  \
# count      24666.000000   24666.000000  24666.000000  24666.000000
# mean          12.751275      77.274550      5.223284      0.758570
# std            9.812288      17.526145      2.106340      2.980807
# min          -14.295035      10.000000      1.949387    -22.874004
# 25%            4.472024      65.000000      2.764084     -1.114717
# 50%           13.011240      80.202504      5.982118      0.719950
# 75%           21.000000      92.719761      7.450969      2.223388
# max           35.392082     106.184456      8.849767     14.802617
#
#         Wind_Y_fcst  Temperature_obs  Humidity_obs     Cloud_obs  \
# count  24666.000000     24666.000000  24666.000000  24666.000000
# mean     -90.886923        12.885199     72.692947      5.204146
# std      130.867208        10.203520     20.418903      3.585782
# min     -321.545657       -19.300000     10.000000      0.000000
# 25%     -216.193480         4.600000     57.000000      2.000000
# 50%      -98.102032        13.500000     75.000000      6.000000
# 75%       30.055400        21.500000     92.000000      8.000000
# max      147.876934        36.800000     99.000000     10.000000
#
#          Wind_X_obs    Wind_Y_obs  dangjin_floating  dangjin_warehouse  \
# count  2.466600e+04  24666.000000      24666.000000       24666.000000
# mean   5.287990e-01    -52.524640        123.685552          94.503700
# std    1.798051e+00    106.530654        192.543363         147.335088
# min   -9.300000e+00   -272.510860          0.000000           0.000000
# 25%   -2.571758e-16   -116.286849          0.000000           0.000000
# 50%    4.000000e-01      0.000000          1.000000           0.000000
# 75%    1.414133e+00      6.840403        198.000000         150.750000
# max    9.584865e+00    103.366188        753.000000         593.000000
#
#             dangjin       Day_cos       Day_sin      Year_cos      Year_sin
# count  24666.000000  2.466600e+04  2.466600e+04  24666.000000  24666.000000
# mean     140.683329  2.029102e-04  8.404817e-05     -0.012206     -0.024485
# std      220.914041  7.070819e-01  7.071603e-01      0.711240      0.702446
# min        0.000000 -1.000000e+00 -1.000000e+00     -0.999963     -0.999991
# 25%        0.000000 -7.071068e-01 -7.071068e-01     -0.720667     -0.717677
# 50%        0.000000  6.123234e-17  1.224647e-16     -0.030120     -0.051620
# 75%      230.000000  7.071068e-01  7.071068e-01      0.714673      0.674444
# max      867.000000  1.000000e+00  1.000000e+00      1.000000      0.999991

# %%
ulsan_merged.describe()
# Out:
#        Temperature_fcst  Humidity_fcst    Cloud_fcst   Wind_X_fcst  \
# count      24672.000000   24672.000000  24672.000000  24672.000000
# mean          15.218450      67.485090      4.937264      0.878212
# std            8.366440      19.209173      2.793863      2.885066
# min          -12.058004       3.536675      0.666132    -23.068719
# 25%            9.000000      54.346945      1.721060     -0.699109
# 50%           16.000000      70.000000      5.458160      1.024369
# 75%           22.000000      83.887175      7.928428      2.441749
# max           35.153438     101.948882      9.554002     27.985320
#
#         Wind_Y_fcst  Temperature_obs  Humidity_obs     Cloud_obs  \
# count  24672.000000     24672.000000  24672.000000  24672.000000
# mean    -109.617132        14.933856     67.090268      5.024289
# std      128.997712         8.800469     23.187600      3.954957
# min     -320.214707       -12.000000      7.000000      0.000000
# 25%     -239.422041         8.100000     49.000000      0.000000
# 50%     -130.593860        15.600000     69.000000      6.000000
# 75%       16.957416        21.800000     87.000000      9.000000
# max      148.848230        36.500000     98.000000     10.000000
#
#          Wind_X_obs    Wind_Y_obs         ulsan       Day_cos       Day_sin  \
# count  2.467200e+04  24672.000000  24672.000000  2.467200e+04  2.467200e+04
# mean   7.569420e-01    -77.185893     64.886795 -7.400137e-17 -7.399462e-17
# std    1.781746e+00    114.375400    101.115233  7.071211e-01  7.071211e-01
# min   -1.014868e+01   -272.510860      0.000000 -1.000000e+00 -1.000000e+00
# 25%   -2.939152e-16   -205.692035      0.000000 -7.071068e-01 -7.071068e-01
# 50%    9.641814e-01    -68.404029      0.000000 -6.123234e-17  6.123234e-17
# 75%    1.915111e+00      6.840403    104.000000  7.071068e-01  7.071068e-01
# max    6.700000e+00    103.366188    384.000000  1.000000e+00  1.000000e+00
#
#            Year_cos      Year_sin
# count  24672.000000  24672.000000
# mean      -0.012428     -0.024571
# std        0.711296      0.702382
# min       -0.999963     -0.999991
# 25%       -0.720667     -0.717677
# 50%       -0.038721     -0.051620
# 75%        0.705564      0.674444
# max        1.000000      0.999991

# %% [markdown]
# ## Pearson coefficient heatmap

# %%
dangjin_merged.columns
# Out:
# Index(['Temperature_fcst', 'Humidity_fcst', 'Cloud_fcst', 'Wind_X_fcst',
#        'Wind_Y_fcst', 'time', 'Temperature_obs', 'Humidity_obs', 'Cloud_obs',
#        'Wind_X_obs', 'Wind_Y_obs', 'dangjin_floating', 'dangjin_warehouse',
#        'dangjin', 'Day_cos', 'Day_sin', 'Year_cos', 'Year_sin'],
#       dtype='object')

# %%
# column name list
obs_column_name = list(dangjin_merged.columns[1:6])
fcst_column_name = list(dangjin_merged.columns[6:11])
energy_column_name = list(dangjin_merged.columns[11:14])
dangjin_column_name = list(dangjin_merged.columns[13:14])
seasonality_column_name = list(dangjin_merged.columns[-4:])

# %%
# corr function
def show_corr_heatmap(data, col_name_list, figsize=(12,5)):
    corr = data.loc[:,col_name_list].corr()
    mask = np.zeros_like(corr)
    for i in range(mask.shape[0]):
        mask[i,i]=True

    plt.figure(figsize=figsize)
    sns.heatmap(corr,annot=True,mask=mask,cmap='coolwarm',vmin=-1,vmax=1)
    plt.show()

# %%
# within energy
show_corr_heatmap(dangjin_merged, energy_column_name, figsize=(8,3))

# %%
# within obs
show_corr_heatmap(dangjin_merged, obs_column_name)

# %%
# within fcst
show_corr_heatmap(dangjin_merged, fcst_column_name)

# %%
# dangjin - obs
show_corr_heatmap(dangjin_merged, dangjin_column_name+obs_column_name)

# %%
# dangjin - fcst
show_corr_heatmap(dangjin_merged, dangjin_column_name+fcst_column_name)

# %%
# dangjin - seasonality
show_corr_heatmap(dangjin_merged, dangjin_column_name+seasonality_column_name)

# %%
# obs - fcst
show_corr_heatmap(dangjin_merged, obs_column_name+fcst_column_name)

# %% [markdown]
# ## Ulsan

# %%
obs_column_name = list(ulsan_merged.columns[1:6])
fcst_column_name = list(ulsan_merged.columns[6:11])
ulsan_column_name = list(ulsan_merged.columns[11:12])
seasonality_column_name = list(ulsan_merged.columns[-4:])

# %%
# obs
show_corr_heatmap(ulsan_merged, obs_column_name)

# %%
# fcst
show_corr_heatmap(ulsan_merged, fcst_column_name)

# %%
# ulsan - obs
show_corr_heatmap(ulsan_merged, ulsan_column_name+obs_column_name)

# %%
# ulsan - fcst
show_corr_heatmap(ulsan_merged, ulsan_column_name+fcst_column_name)

# %%
# ulsan - seasonality
show_corr_heatmap(ulsan_merged, ulsan_column_name+seasonality_column_name)

# %%
# obs - fcst
show_corr_heatmap(ulsan_merged, obs_column_name+fcst_column_name)
