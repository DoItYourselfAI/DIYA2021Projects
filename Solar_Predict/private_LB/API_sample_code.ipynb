# %% [markdown]
# ## Private LB API sample code

# %%
from privateLB_API import API

key = 'sNfoTDclWrvFGpIEFDEXvj+EaCjLrOILF7IYehdRCcYBxnMP0zna40R1UmY6qfWBG0gJ16c3T8ManHwvhACk7w=='

# 날짜는 최근의 일자로 업데이트 해줘야만 불러올 수 있습니다.
dj = API('20210612','2000','dangjin',key).get_data(gap=1, preprocess=True, itp_method='quadratic')
uls = API('20210612','2000','ulsan',key).get_data(gap=1, preprocess=True)

# %%
help(API.__init__)
# Out:
# Help on function __init__ in module privateLB:
#
# __init__(self, base_date, base_time, location, key)
#     base_date: str, format:'YYYYMMDD'(e.g. '20210522'). 예보 발표일자. API로는 최근 1일간의 자료만을 불러올 수 있다는 점 유의.
#     base_time: str, format: 'HHMM'(e.g. '2000' for 20시). 예보 발표시각. 0200, 0500, 0800, 1100, 1400, 1700, 2000, 2300 중 하나여야 함.
#     location: str, 'dangjin' or 'ulsan'.
#     key: 기상청 API 일반 인증키(decoding)

# %%
help(API.get_data)
# Out:
# Help on function get_data in module privateLB:
#
# get_data(self, gap=1, preprocess=True, itp_method='linear')
#     gap: int; 몇 일 뒤를 예측할 것인지. Default = 1
#     preprocess: bool, True by default. Set preprocess = False to get raw data.
#     itp_method: str, interpolation method supported by pandas.DataFrame.interpolate. Commonly used are 'linear' and 'quadratic'.

# %%
display(dj)
display(uls)
# Out:
#                   time   Humidity     Cloud  Temperature       Day_cos  \
# 1  2021-06-03 01:00:00  84.381229  0.721148    18.736030  9.659258e-01
# 2  2021-06-03 02:00:00  87.714562  0.721148    18.402697  8.660254e-01
# 3  2021-06-03 03:00:00  90.000000  1.000000    18.000000  7.071068e-01
# 4  2021-06-03 04:00:00  91.237542  1.557704    17.527939  5.000000e-01
# 5  2021-06-03 05:00:00  91.363973  2.337630    17.055879  2.588190e-01
# 6  2021-06-03 06:00:00  90.000000  3.000000    17.000000  6.123234e-17
# 7  2021-06-03 07:00:00  87.082408  3.488184    17.429667 -2.588190e-01
# 8  2021-06-03 08:00:00  82.990490  3.808626    18.262030 -5.000000e-01
# 9  2021-06-03 09:00:00  80.000000  4.000000    19.000000 -7.071068e-01
# 10 2021-06-03 10:00:00  78.490230  4.068750    19.560727 -8.660254e-01
# 11 2021-06-03 11:00:00  78.470864  4.032835    19.927495 -9.659258e-01
# 12 2021-06-03 12:00:00  80.000000  4.000000    20.000000 -1.000000e+00
# ...
